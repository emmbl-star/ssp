# %%
import pandas as pd

# %%
data = pd.read_csv('raw_data/startup_data.csv')
data = pd.DataFrame(data)
data.columns
# Out:
# Index(['Unnamed: 0', 'state_code', 'latitude', 'longitude', 'zip_code', 'id',
#        'city', 'Unnamed: 6', 'name', 'labels', 'founded_at', 'closed_at',
#        'first_funding_at', 'last_funding_at', 'age_first_funding_year',
#        'age_last_funding_year', 'age_first_milestone_year',
#        'age_last_milestone_year', 'relationships', 'funding_rounds',
#        'funding_total_usd', 'milestones', 'state_code.1', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'object_id', 'has_VC', 'has_angel', 'has_roundA',
#        'has_roundB', 'has_roundC', 'has_roundD', 'avg_participants',
#        'is_top500', 'status'],
#       dtype='object')

# %%
# data.loc[0]
# data['Unnamed: 0'].max()
# data['closed_at'].isna().sum()
# Out:
# np.int64(588)

# %%
# Unnamed: 0: An unnamed column, possibly representing the index or a placeholder for missing data. => More values than rows, max. value = 1153 (drop)
# state_code: The state code where the startup is located. => 35 independend US-states
# latitude: The latitude coordinates of the startup’s location (the north-south position).
# longitude: The longitude coordinates of the startup’s location (the east-west position).
# zip_code: The postal code of the startup's headquarters.
# id: A unique identifier for each startup. => 922 different values (index)
# city: The city where the startup is located. => 221 cities
# Unnamed: 6: Another unnamed column, likely a placeholder for missing data or unused information.(drop)
# name: The name of the startup. => 922 different names
# labels: Specific labels or tags associated with the startup, possibly describing the industry or business model. => binary
# founded_at: The date the startup was founded. => Format: month/day/year
# closed_at: The date the startup closed down (if applicable). => Format: month/day/year, 588 start-ups still operating
# first_funding_at: The date the startup received its first funding.
# last_funding_at: The date of the most recent funding round.
# age_first_funding_year: The age of the startup in years when it received its first funding.
# age_last_funding_year: The age of the startup in years when it received its last funding.
# age_first_milestone_year: The age of the startup when it achieved its first major milestone.
# age_last_milestone_year: The age of the startup when it achieved its last major milestone.
# relationships: The number of professional relationships or connections the startup has established.
# funding_rounds: The total number of funding rounds the startup has gone through.
# funding_total_usd: The total amount of funding the startup has raised, in US dollars.
# milestones: The total number of significant milestones the startup has achieved.
# state_code.1: A duplicate or secondary state code, potentially for validation or categorization purposes.
# is_CA: A binary variable indicating whether the startup is located in California (1 for Yes, 0 for No).
# is_NY: A binary variable indicating whether the startup is located in New York (1 for Yes, 0 for No).
# is_MA: A binary variable indicating whether the startup is located in Massachusetts (1 for Yes, 0 for No).
# is_TX: A binary variable indicating whether the startup is located in Texas (1 for Yes, 0 for No).
# is_otherstate: A binary variable indicating whether the startup is located in any other state besides CA, NY, MA, or TX (1 for Yes, 0 for No).
# category_code: The industry or category to which the startup belongs (e.g., software, biotech, ecommerce).
# is_software: A binary variable indicating whether the startup operates in the software industry (1 for Yes, 0 for No).
# is_web: A binary variable indicating whether the startup operates in the web industry (1 for Yes, 0 for No).
# is_mobile: A binary variable indicating whether the startup operates in the mobile industry (1 for Yes, 0 for No).
# is_enterprise: A binary variable indicating whether the startup operates in the enterprise industry (1 for Yes, 0 for No).
# is_advertising: A binary variable indicating whether the startup operates in the advertising industry (1 for Yes, 0 for No).
# is_gamesvideo: A binary variable indicating whether the startup operates in the games or video industry (1 for Yes, 0 for No).
# is_ecommerce: A binary variable indicating whether the startup operates in the ecommerce industry (1 for Yes, 0 for No).
# is_biotech: A binary variable indicating whether the startup operates in the biotech industry (1 for Yes, 0 for No).
# is_consulting: A binary variable indicating whether the startup operates in the consulting industry (1 for Yes, 0 for No).
# is_othercategory: A binary variable indicating whether the startup operates in any other industry besides those listed (1 for Yes, 0 for No).
# object_id: A unique identifier for each object (startup) in the dataset.
# has_VC: A binary variable indicating whether the startup has venture capital funding (1 for Yes, 0 for No).
# has_angel: A binary variable indicating whether the startup has received angel funding (1 for Yes, 0 for No).
# has_roundA: A binary variable indicating whether the startup has gone through a Series A funding round (1 for Yes, 0 for No).
# has_roundB: A binary variable indicating whether the startup has gone through a Series B funding round (1 for Yes, 0 for No).
# has_roundC: A binary variable indicating whether the startup has gone through a Series C funding round (1 for Yes, 0 for No).
# has_roundD: A binary variable indicating whether the startup has gone through a Series D funding round (1 for Yes, 0 for No).
# avg_participants: The average number of participants involved in the startup's funding rounds.
# is_top500: A binary variable indicating whether the startup is in the top 500 startups (1 for Yes, 0 for No).
# status: The current status of the startup (e.g., acquired, closed).
